# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
# データのロード
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# 正規化（0〜1にスケーリング）
X_train = X_train.astype('float32') / 255.0
X_test  = X_test.astype('float32') / 255.0

# ラベルをOne-Hotエンコーディング
y_train = to_categorical(y_train, 10)
y_test  = to_categorical(y_test, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# ### 1層MLP

# %%
model = Sequential()

# 入力層 → Flattenで1次元に
model.add(Flatten(input_shape=(32, 32, 3)))

# 隠れ層（ユニット数は調整可）
model.add(Dense(512, activation='relu'))

# 出力層（10クラス分類）
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=100,
    validation_split=0.1,
    verbose=2
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-7-2953636440.py in <cell line: 0>()
# ----> 1 model.compile(
#       2     loss='categorical_crossentropy',
#       3     optimizer='adam',
#       4     metrics=['accuracy'],
#       5     early_stopping=10
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/tracking.py in wrapper(*args, **kwargs)
#      24     def wrapper(*args, **kwargs):
#      25         with DotNotTrackScope():
# ---> 26             return fn(*args, **kwargs)
#      27
#      28     return wrapper
#
# TypeError: Trainer.compile() got an unexpected keyword argument 'early_stopping'

# %%
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test accuracy: 0.4888

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)
# Out:
# Epoch 1/20
# 352/352 - 5s - 15ms/step - accuracy: 0.3155 - loss: 1.9248 - val_accuracy: 0.3858 - val_loss: 1.7517
# Epoch 2/20
# 352/352 - 2s - 5ms/step - accuracy: 0.3958 - loss: 1.6919 - val_accuracy: 0.4250 - val_loss: 1.6331
# Epoch 3/20
# 352/352 - 1s - 3ms/step - accuracy: 0.4262 - loss: 1.6074 - val_accuracy: 0.4410 - val_loss: 1.5858
# Epoch 4/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4493 - loss: 1.5480 - val_accuracy: 0.4386 - val_loss: 1.5958
# Epoch 5/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4647 - loss: 1.5054 - val_accuracy: 0.4572 - val_loss: 1.5262
# Epoch 6/20
# 352/352 - 1s - 3ms/step - accuracy: 0.4782 - loss: 1.4695 - val_accuracy: 0.4572 - val_loss: 1.5347
# Epoch 7/20
# 352/352 - 1s - 3ms/step - accuracy: 0.4860 - loss: 1.4410 - val_accuracy: 0.4838 - val_loss: 1.4611
# Epoch 8/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4980 - loss: 1.4073 - val_accuracy: 0.4968 - val_loss: 1.4334
# Epoch 9/20
# 352/352 - 2s - 4ms/step - accuracy: 0.5066 - loss: 1.3882 - val_accuracy: 0.5000 - val_loss: 1.4213
# Epoch 10/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5149 - loss: 1.3576 - val_accuracy: 0.4968 - val_loss: 1.4112
# Epoch 11/20
# 352/352 - 2s - 7ms/step - accuracy: 0.5210 - loss: 1.3393 - val_accuracy: 0.5004 - val_loss: 1.4170
# Epoch 12/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5317 - loss: 1.3167 - val_accuracy: 0.5044 - val_loss: 1.3953
# Epoch 13/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5435 - loss: 1.2818 - val_accuracy: 0.5172 - val_loss: 1.3846
# Epoch 14/20
# 352/352 - 1s - 3ms/step - accuracy: 0.5473 - loss: 1.2686 - val_accuracy: 0.5114 - val_loss: 1.3927
# Epoch 15/20
# 352/352 - 1s - 3ms/step - accuracy: 0.5544 - loss: 1.2505 - val_accuracy: 0.5260 - val_loss: 1.3714
# Epoch 16/20
# 352/352 - 1s - 3ms/step - accuracy: 0.5663 - loss: 1.2214 - val_accuracy: 0.5030 - val_loss: 1.4162
# Epoch 17/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5688 - loss: 1.2073 - val_accuracy: 0.5158 - val_loss: 1.3934
# Epoch 18/20
# 352/352 - 2s - 5ms/step - accuracy: 0.5774 - loss: 1.1928 - val_accuracy: 0.5230 - val_loss: 1.3670
# Epoch 19/20
# 352/352 - 1s - 3ms/step - accuracy: 0.5800 - loss: 1.1774 - val_accuracy: 0.5132 - val_loss: 1.4117
# Epoch 20/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5859 - loss: 1.1617 - val_accuracy: 0.5244 - val_loss: 1.3666

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test accuracy: 0.5136

# %%
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(1024, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)
# Out:
# Epoch 1/20
# 352/352 - 6s - 16ms/step - accuracy: 0.3115 - loss: 1.9114 - val_accuracy: 0.3732 - val_loss: 1.7476
# Epoch 2/20
# 352/352 - 2s - 5ms/step - accuracy: 0.3936 - loss: 1.6869 - val_accuracy: 0.4072 - val_loss: 1.6787
# Epoch 3/20
# 352/352 - 2s - 7ms/step - accuracy: 0.4265 - loss: 1.5972 - val_accuracy: 0.4346 - val_loss: 1.5897
# Epoch 4/20
# 352/352 - 3s - 7ms/step - accuracy: 0.4474 - loss: 1.5405 - val_accuracy: 0.4498 - val_loss: 1.5462
# Epoch 5/20
# 352/352 - 3s - 7ms/step - accuracy: 0.4695 - loss: 1.4836 - val_accuracy: 0.4620 - val_loss: 1.5063
# Epoch 6/20
# 352/352 - 2s - 4ms/step - accuracy: 0.4830 - loss: 1.4452 - val_accuracy: 0.4858 - val_loss: 1.4629
# Epoch 7/20
# 352/352 - 2s - 5ms/step - accuracy: 0.4995 - loss: 1.4024 - val_accuracy: 0.4786 - val_loss: 1.4964
# Epoch 8/20
# 352/352 - 2s - 6ms/step - accuracy: 0.5113 - loss: 1.3695 - val_accuracy: 0.4920 - val_loss: 1.4268
# Epoch 9/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5207 - loss: 1.3432 - val_accuracy: 0.4980 - val_loss: 1.4167
# Epoch 10/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5303 - loss: 1.3120 - val_accuracy: 0.4960 - val_loss: 1.4260
# Epoch 11/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5426 - loss: 1.2774 - val_accuracy: 0.4924 - val_loss: 1.4214
# Epoch 12/20
# 352/352 - 3s - 8ms/step - accuracy: 0.5505 - loss: 1.2520 - val_accuracy: 0.4970 - val_loss: 1.4168
# Epoch 13/20
# 352/352 - 3s - 7ms/step - accuracy: 0.5648 - loss: 1.2183 - val_accuracy: 0.5146 - val_loss: 1.3865
# Epoch 14/20
# 352/352 - 2s - 6ms/step - accuracy: 0.5750 - loss: 1.1875 - val_accuracy: 0.5114 - val_loss: 1.4075
# Epoch 15/20
# 352/352 - 2s - 7ms/step - accuracy: 0.5846 - loss: 1.1628 - val_accuracy: 0.5068 - val_loss: 1.4125
# Epoch 16/20
# 352/352 - 3s - 7ms/step - accuracy: 0.5952 - loss: 1.1263 - val_accuracy: 0.5058 - val_loss: 1.4148
# Epoch 17/20
# 352/352 - 1s - 4ms/step - accuracy: 0.6039 - loss: 1.1022 - val_accuracy: 0.5264 - val_loss: 1.3807
# Epoch 18/20
# 352/352 - 3s - 8ms/step - accuracy: 0.6167 - loss: 1.0649 - val_accuracy: 0.5168 - val_loss: 1.4112
# Epoch 19/20
# 352/352 - 2s - 6ms/step - accuracy: 0.6298 - loss: 1.0309 - val_accuracy: 0.5212 - val_loss: 1.4188
# Epoch 20/20
# 352/352 - 1s - 4ms/step - accuracy: 0.6399 - loss: 1.0023 - val_accuracy: 0.5180 - val_loss: 1.4258

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test accuracy: 0.5127

# %%
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))  # 50%のDropout
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 352/352 - 7s - 19ms/step - accuracy: 0.2001 - loss: 2.1475 - val_accuracy: 0.2992 - val_loss: 1.9881
# Epoch 2/20
# 352/352 - 6s - 17ms/step - accuracy: 0.2326 - loss: 2.0373 - val_accuracy: 0.3114 - val_loss: 1.9473
# Epoch 3/20
# 352/352 - 2s - 4ms/step - accuracy: 0.2397 - loss: 2.0115 - val_accuracy: 0.3334 - val_loss: 1.9378
# Epoch 4/20
# 352/352 - 2s - 6ms/step - accuracy: 0.2462 - loss: 1.9940 - val_accuracy: 0.3334 - val_loss: 1.9278
# Epoch 5/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2544 - loss: 1.9803 - val_accuracy: 0.3290 - val_loss: 1.9185
# Epoch 6/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2568 - loss: 1.9705 - val_accuracy: 0.3226 - val_loss: 1.9526
# Epoch 7/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2632 - loss: 1.9583 - val_accuracy: 0.3258 - val_loss: 1.9350
# Epoch 8/20
# 352/352 - 1s - 4ms/step - accuracy: 0.2669 - loss: 1.9510 - val_accuracy: 0.3132 - val_loss: 1.9454
# Epoch 9/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2704 - loss: 1.9457 - val_accuracy: 0.3246 - val_loss: 1.9213
# Epoch 10/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2705 - loss: 1.9415 - val_accuracy: 0.3216 - val_loss: 1.9328
# Epoch 11/20
# 352/352 - 1s - 4ms/step - accuracy: 0.2816 - loss: 1.9333 - val_accuracy: 0.3512 - val_loss: 1.8909
# Epoch 12/20
# 352/352 - 2s - 5ms/step - accuracy: 0.2810 - loss: 1.9271 - val_accuracy: 0.3238 - val_loss: 1.9280
# Epoch 13/20
# 352/352 - 2s - 6ms/step - accuracy: 0.2814 - loss: 1.9315 - val_accuracy: 0.3326 - val_loss: 1.9191
# Epoch 14/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2880 - loss: 1.9159 - val_accuracy: 0.3356 - val_loss: 1.9099
# Epoch 15/20
# 352/352 - 1s - 4ms/step - accuracy: 0.2861 - loss: 1.9162 - val_accuracy: 0.3234 - val_loss: 1.9212
# Epoch 16/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2869 - loss: 1.9152 - val_accuracy: 0.3116 - val_loss: 1.9371
# Epoch 17/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2912 - loss: 1.9082 - val_accuracy: 0.3298 - val_loss: 1.9067
# Epoch 18/20
# 352/352 - 1s - 3ms/step - accuracy: 0.2920 - loss: 1.9076 - val_accuracy: 0.3404 - val_loss: 1.9165
# Epoch 19/20
# 352/352 - 1s - 4ms/step - accuracy: 0.2912 - loss: 1.9049 - val_accuracy: 0.3380 - val_loss: 1.9103
# Epoch 20/20
# 352/352 - 1s - 4ms/step - accuracy: 0.2922 - loss: 1.9041 - val_accuracy: 0.3136 - val_loss: 1.9455
# Test accuracy: 0.3207

# %%
from tensorflow.keras.layers import BatchNormalization

model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Dense(512, activation='relu'))
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 352/352 - 7s - 21ms/step - accuracy: 0.4079 - loss: 1.6677 - val_accuracy: 0.3008 - val_loss: 1.9887
# Epoch 2/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4842 - loss: 1.4477 - val_accuracy: 0.3874 - val_loss: 1.7039
# Epoch 3/20
# 352/352 - 3s - 7ms/step - accuracy: 0.5215 - loss: 1.3372 - val_accuracy: 0.4248 - val_loss: 1.6738
# Epoch 4/20
# 352/352 - 2s - 5ms/step - accuracy: 0.5487 - loss: 1.2601 - val_accuracy: 0.4834 - val_loss: 1.4684
# Epoch 5/20
# 352/352 - 2s - 6ms/step - accuracy: 0.5738 - loss: 1.1949 - val_accuracy: 0.4942 - val_loss: 1.4528
# Epoch 6/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5945 - loss: 1.1373 - val_accuracy: 0.4710 - val_loss: 1.5150
# Epoch 7/20
# 352/352 - 1s - 4ms/step - accuracy: 0.6099 - loss: 1.0896 - val_accuracy: 0.4614 - val_loss: 1.5710
# Epoch 8/20
# 352/352 - 3s - 8ms/step - accuracy: 0.6314 - loss: 1.0342 - val_accuracy: 0.5172 - val_loss: 1.3943
# Epoch 9/20
# 352/352 - 1s - 4ms/step - accuracy: 0.6486 - loss: 0.9888 - val_accuracy: 0.5042 - val_loss: 1.4022
# Epoch 10/20
# 352/352 - 1s - 4ms/step - accuracy: 0.6640 - loss: 0.9418 - val_accuracy: 0.4972 - val_loss: 1.4865
# Epoch 11/20
# 352/352 - 3s - 7ms/step - accuracy: 0.6805 - loss: 0.8930 - val_accuracy: 0.4906 - val_loss: 1.5592
# Epoch 12/20
# 352/352 - 2s - 7ms/step - accuracy: 0.7005 - loss: 0.8420 - val_accuracy: 0.4660 - val_loss: 1.7321
# Epoch 13/20
# 352/352 - 3s - 7ms/step - accuracy: 0.7156 - loss: 0.8007 - val_accuracy: 0.4592 - val_loss: 1.8176
# Epoch 14/20
# 352/352 - 1s - 4ms/step - accuracy: 0.7299 - loss: 0.7549 - val_accuracy: 0.4750 - val_loss: 1.7747
# Epoch 15/20
# 352/352 - 1s - 4ms/step - accuracy: 0.7461 - loss: 0.7072 - val_accuracy: 0.4798 - val_loss: 1.7609
# Epoch 16/20
# 352/352 - 2s - 5ms/step - accuracy: 0.7638 - loss: 0.6622 - val_accuracy: 0.4968 - val_loss: 1.8053
# Epoch 17/20
# 352/352 - 2s - 6ms/step - accuracy: 0.7786 - loss: 0.6200 - val_accuracy: 0.4864 - val_loss: 1.8228
# Epoch 18/20
# 352/352 - 3s - 7ms/step - accuracy: 0.7910 - loss: 0.5834 - val_accuracy: 0.4882 - val_loss: 1.9313
# Epoch 19/20
# 352/352 - 3s - 7ms/step - accuracy: 0.8095 - loss: 0.5349 - val_accuracy: 0.4828 - val_loss: 1.9416
# Epoch 20/20
# 352/352 - 1s - 4ms/step - accuracy: 0.8205 - loss: 0.5011 - val_accuracy: 0.4754 - val_loss: 2.0638
# Test accuracy: 0.4784

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 352/352 - 9s - 25ms/step - accuracy: 0.3125 - loss: 1.9550 - val_accuracy: 0.3576 - val_loss: 1.7915
# Epoch 2/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4009 - loss: 1.6802 - val_accuracy: 0.3880 - val_loss: 1.6607
# Epoch 3/20
# 352/352 - 2s - 5ms/step - accuracy: 0.4290 - loss: 1.5976 - val_accuracy: 0.4132 - val_loss: 1.6363
# Epoch 4/20
# 352/352 - 2s - 7ms/step - accuracy: 0.4499 - loss: 1.5431 - val_accuracy: 0.4438 - val_loss: 1.5318
# Epoch 5/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4644 - loss: 1.4988 - val_accuracy: 0.4220 - val_loss: 1.5994
# Epoch 6/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4790 - loss: 1.4615 - val_accuracy: 0.4772 - val_loss: 1.4776
# Epoch 7/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4865 - loss: 1.4372 - val_accuracy: 0.4506 - val_loss: 1.5440
# Epoch 8/20
# 352/352 - 1s - 4ms/step - accuracy: 0.4979 - loss: 1.4103 - val_accuracy: 0.4206 - val_loss: 1.5772
# Epoch 9/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5074 - loss: 1.3864 - val_accuracy: 0.4920 - val_loss: 1.4530
# Epoch 10/20
# 352/352 - 3s - 9ms/step - accuracy: 0.5115 - loss: 1.3702 - val_accuracy: 0.4802 - val_loss: 1.4299
# Epoch 11/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5146 - loss: 1.3527 - val_accuracy: 0.4892 - val_loss: 1.4036
# Epoch 12/20
# 352/352 - 3s - 7ms/step - accuracy: 0.5256 - loss: 1.3366 - val_accuracy: 0.5044 - val_loss: 1.3873
# Epoch 13/20
# 352/352 - 3s - 7ms/step - accuracy: 0.5309 - loss: 1.3234 - val_accuracy: 0.4788 - val_loss: 1.4797
# Epoch 14/20
# 352/352 - 2s - 7ms/step - accuracy: 0.5333 - loss: 1.3114 - val_accuracy: 0.5070 - val_loss: 1.3921
# Epoch 15/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5354 - loss: 1.3033 - val_accuracy: 0.5038 - val_loss: 1.3897
# Epoch 16/20
# 352/352 - 3s - 7ms/step - accuracy: 0.5467 - loss: 1.2794 - val_accuracy: 0.4914 - val_loss: 1.4137
# Epoch 17/20
# 352/352 - 1s - 4ms/step - accuracy: 0.5488 - loss: 1.2722 - val_accuracy: 0.4610 - val_loss: 1.4964
# Epoch 18/20
# 352/352 - 3s - 7ms/step - accuracy: 0.5534 - loss: 1.2570 - val_accuracy: 0.5020 - val_loss: 1.3993
# Epoch 19/20
# 352/352 - 2s - 7ms/step - accuracy: 0.5548 - loss: 1.2501 - val_accuracy: 0.5260 - val_loss: 1.3497
# Epoch 20/20
# 352/352 - 3s - 8ms/step - accuracy: 0.5580 - loss: 1.2399 - val_accuracy: 0.5078 - val_loss: 1.3877
# Test accuracy: 0.4987

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

# 畳み込み層＋プーリング層（特徴抽出）
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Flatten → 全結合
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 352/352 - 13s - 37ms/step - accuracy: 0.3296 - loss: 1.8411 - val_accuracy: 0.4960 - val_loss: 1.4573
# Epoch 2/20
# 352/352 - 2s - 6ms/step - accuracy: 0.4642 - loss: 1.4844 - val_accuracy: 0.5574 - val_loss: 1.2904
# Epoch 3/20
# 352/352 - 2s - 6ms/step - accuracy: 0.5121 - loss: 1.3603 - val_accuracy: 0.6008 - val_loss: 1.1433
# Epoch 4/20
# 352/352 - 2s - 5ms/step - accuracy: 0.5455 - loss: 1.2769 - val_accuracy: 0.6224 - val_loss: 1.0899
# Epoch 5/20
# 352/352 - 3s - 7ms/step - accuracy: 0.5714 - loss: 1.2124 - val_accuracy: 0.6406 - val_loss: 1.0452
# Epoch 6/20
# 352/352 - 2s - 7ms/step - accuracy: 0.5868 - loss: 1.1619 - val_accuracy: 0.6682 - val_loss: 0.9712
# Epoch 7/20
# 352/352 - 3s - 8ms/step - accuracy: 0.6014 - loss: 1.1280 - val_accuracy: 0.6654 - val_loss: 0.9627
# Epoch 8/20
# 352/352 - 2s - 6ms/step - accuracy: 0.6117 - loss: 1.0956 - val_accuracy: 0.6882 - val_loss: 0.9253
# Epoch 9/20
# 352/352 - 2s - 5ms/step - accuracy: 0.6255 - loss: 1.0630 - val_accuracy: 0.6906 - val_loss: 0.8911
# Epoch 10/20
# 352/352 - 2s - 5ms/step - accuracy: 0.6360 - loss: 1.0314 - val_accuracy: 0.6948 - val_loss: 0.8834
# Epoch 11/20
# 352/352 - 2s - 5ms/step - accuracy: 0.6419 - loss: 1.0104 - val_accuracy: 0.7072 - val_loss: 0.8479
# Epoch 12/20
# 352/352 - 3s - 8ms/step - accuracy: 0.6492 - loss: 0.9939 - val_accuracy: 0.7120 - val_loss: 0.8518
# Epoch 13/20
# 352/352 - 2s - 7ms/step - accuracy: 0.6568 - loss: 0.9704 - val_accuracy: 0.7114 - val_loss: 0.8444
# Epoch 14/20
# 352/352 - 2s - 5ms/step - accuracy: 0.6615 - loss: 0.9562 - val_accuracy: 0.7146 - val_loss: 0.8413
# Epoch 15/20
# 352/352 - 2s - 5ms/step - accuracy: 0.6691 - loss: 0.9364 - val_accuracy: 0.7190 - val_loss: 0.8019
# Epoch 16/20
# 352/352 - 3s - 7ms/step - accuracy: 0.6769 - loss: 0.9141 - val_accuracy: 0.7142 - val_loss: 0.8127
# Epoch 17/20
# 352/352 - 3s - 7ms/step - accuracy: 0.6778 - loss: 0.9090 - val_accuracy: 0.7020 - val_loss: 0.8553
# Epoch 18/20
# 352/352 - 2s - 7ms/step - accuracy: 0.6814 - loss: 0.8923 - val_accuracy: 0.7254 - val_loss: 0.8012
# Epoch 19/20
# 352/352 - 2s - 5ms/step - accuracy: 0.6882 - loss: 0.8782 - val_accuracy: 0.7276 - val_loss: 0.7847
# Epoch 20/20
# 352/352 - 2s - 5ms/step - accuracy: 0.6909 - loss: 0.8699 - val_accuracy: 0.7346 - val_loss: 0.7782
# Test accuracy: 0.7196

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

base_model = VGG16(include_top=False, weights='imagenet', input_shape=(32, 32, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dense(10, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=x)

# 転移学習：base_modelの重みは凍結しておく（fine-tuning）
for layer in base_model.layers:
    layer.trainable = False

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 352/352 - 14s - 40ms/step - accuracy: 0.5038 - loss: 1.4329 - val_accuracy: 0.5468 - val_loss: 1.2856
# Epoch 2/20
# 352/352 - 8s - 24ms/step - accuracy: 0.5775 - loss: 1.2167 - val_accuracy: 0.5928 - val_loss: 1.1812
# Epoch 3/20
# 352/352 - 10s - 28ms/step - accuracy: 0.5976 - loss: 1.1579 - val_accuracy: 0.5942 - val_loss: 1.1588
# Epoch 4/20
# 352/352 - 11s - 31ms/step - accuracy: 0.6106 - loss: 1.1174 - val_accuracy: 0.6046 - val_loss: 1.1320
# Epoch 5/20
# 352/352 - 8s - 24ms/step - accuracy: 0.6240 - loss: 1.0817 - val_accuracy: 0.6148 - val_loss: 1.1149
# Epoch 6/20
# 352/352 - 10s - 28ms/step - accuracy: 0.6335 - loss: 1.0522 - val_accuracy: 0.6212 - val_loss: 1.1014
# Epoch 7/20
# 352/352 - 10s - 29ms/step - accuracy: 0.6428 - loss: 1.0230 - val_accuracy: 0.6100 - val_loss: 1.1092
# Epoch 8/20
# 352/352 - 8s - 23ms/step - accuracy: 0.6544 - loss: 0.9988 - val_accuracy: 0.6202 - val_loss: 1.0877
# Epoch 9/20
# 352/352 - 8s - 23ms/step - accuracy: 0.6626 - loss: 0.9729 - val_accuracy: 0.6292 - val_loss: 1.0860
# Epoch 10/20
# 352/352 - 11s - 31ms/step - accuracy: 0.6696 - loss: 0.9494 - val_accuracy: 0.6300 - val_loss: 1.0764
# Epoch 11/20
# 352/352 - 10s - 29ms/step - accuracy: 0.6791 - loss: 0.9239 - val_accuracy: 0.6298 - val_loss: 1.0765
# Epoch 12/20
# 352/352 - 10s - 28ms/step - accuracy: 0.6856 - loss: 0.9054 - val_accuracy: 0.6284 - val_loss: 1.0737
# Epoch 13/20
# 352/352 - 10s - 29ms/step - accuracy: 0.6938 - loss: 0.8821 - val_accuracy: 0.6376 - val_loss: 1.0647
# Epoch 14/20
# 352/352 - 10s - 29ms/step - accuracy: 0.7000 - loss: 0.8623 - val_accuracy: 0.6364 - val_loss: 1.0736
# Epoch 15/20
# 352/352 - 8s - 23ms/step - accuracy: 0.7086 - loss: 0.8445 - val_accuracy: 0.6226 - val_loss: 1.0934
# Epoch 16/20
# 352/352 - 8s - 23ms/step - accuracy: 0.7133 - loss: 0.8255 - val_accuracy: 0.6368 - val_loss: 1.0730
# Epoch 17/20
# 352/352 - 8s - 23ms/step - accuracy: 0.7236 - loss: 0.8034 - val_accuracy: 0.6376 - val_loss: 1.0772
# Epoch 18/20
# 352/352 - 10s - 29ms/step - accuracy: 0.7270 - loss: 0.7880 - val_accuracy: 0.6376 - val_loss: 1.0900
# Epoch 19/20
# 352/352 - 11s - 30ms/step - accuracy: 0.7322 - loss: 0.7712 - val_accuracy: 0.6370 - val_loss: 1.1109
# Epoch 20/20
# 352/352 - 10s - 29ms/step - accuracy: 0.7399 - loss: 0.7539 - val_accuracy: 0.6324 - val_loss: 1.0922
# Test accuracy: 0.6217

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.utils import to_categorical

# ResNet50のベースモデルを読み込む（ImageNetで学習済）
base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(32, 32, 3))

# 新しい分類ヘッドを追加
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(10, activation='softmax')(x)

# モデル構築
model = Model(inputs=base_model.input, outputs=predictions)

# 転移学習：ベースモデルの重みを固定（必要ならfine-tuning）
for layer in base_model.layers:
    layer.trainable = False

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 352/352 - 26s - 74ms/step - accuracy: 0.2287 - loss: 2.1265 - val_accuracy: 0.2542 - val_loss: 1.9641
# Epoch 2/20
# 352/352 - 4s - 13ms/step - accuracy: 0.3054 - loss: 1.9202 - val_accuracy: 0.3358 - val_loss: 1.8899
# Epoch 3/20
# 352/352 - 5s - 15ms/step - accuracy: 0.3336 - loss: 1.8550 - val_accuracy: 0.3124 - val_loss: 1.8724
# Epoch 4/20
# 352/352 - 4s - 12ms/step - accuracy: 0.3432 - loss: 1.8194 - val_accuracy: 0.3592 - val_loss: 1.7925
# Epoch 5/20
# 352/352 - 5s - 15ms/step - accuracy: 0.3601 - loss: 1.7836 - val_accuracy: 0.3696 - val_loss: 1.7473
# Epoch 6/20
# 352/352 - 4s - 12ms/step - accuracy: 0.3670 - loss: 1.7663 - val_accuracy: 0.3760 - val_loss: 1.7702
# Epoch 7/20
# 352/352 - 4s - 13ms/step - accuracy: 0.3733 - loss: 1.7467 - val_accuracy: 0.3778 - val_loss: 1.7215
# Epoch 8/20
# 352/352 - 4s - 13ms/step - accuracy: 0.3789 - loss: 1.7364 - val_accuracy: 0.3756 - val_loss: 1.7234
# Epoch 9/20
# 352/352 - 4s - 12ms/step - accuracy: 0.3824 - loss: 1.7201 - val_accuracy: 0.3972 - val_loss: 1.6881
# Epoch 10/20
# 352/352 - 5s - 15ms/step - accuracy: 0.3898 - loss: 1.7026 - val_accuracy: 0.3856 - val_loss: 1.7007
# Epoch 11/20
# 352/352 - 4s - 13ms/step - accuracy: 0.3933 - loss: 1.6960 - val_accuracy: 0.3984 - val_loss: 1.7173
# Epoch 12/20
# 352/352 - 4s - 12ms/step - accuracy: 0.3945 - loss: 1.6930 - val_accuracy: 0.3980 - val_loss: 1.6638
# Epoch 13/20
# 352/352 - 4s - 13ms/step - accuracy: 0.4019 - loss: 1.6745 - val_accuracy: 0.4102 - val_loss: 1.6411
# Epoch 14/20
# 352/352 - 5s - 14ms/step - accuracy: 0.4055 - loss: 1.6673 - val_accuracy: 0.4038 - val_loss: 1.6783
# Epoch 15/20
# 352/352 - 4s - 12ms/step - accuracy: 0.4066 - loss: 1.6620 - val_accuracy: 0.4092 - val_loss: 1.6370
# Epoch 16/20
# 352/352 - 6s - 16ms/step - accuracy: 0.4055 - loss: 1.6681 - val_accuracy: 0.4090 - val_loss: 1.6434
# Epoch 17/20
# 352/352 - 5s - 13ms/step - accuracy: 0.4077 - loss: 1.6555 - val_accuracy: 0.4106 - val_loss: 1.6420
# Epoch 18/20
# 352/352 - 6s - 16ms/step - accuracy: 0.4122 - loss: 1.6515 - val_accuracy: 0.4184 - val_loss: 1.6275
# Epoch 19/20
# 352/352 - 4s - 12ms/step - accuracy: 0.4123 - loss: 1.6474 - val_accuracy: 0.4014 - val_loss: 1.6798
# Epoch 20/20
# 352/352 - 4s - 12ms/step - accuracy: 0.4149 - loss: 1.6416 - val_accuracy: 0.4198 - val_loss: 1.6243
# Test accuracy: 0.4215

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(32, 32, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(10, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# 転移学習：ベースモデルは固定
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 352/352 - 62s - 176ms/step - accuracy: 0.5578 - loss: 1.2664 - val_accuracy: 0.6104 - val_loss: 1.1051
# Epoch 2/20
# 352/352 - 40s - 115ms/step - accuracy: 0.6394 - loss: 1.0295 - val_accuracy: 0.6294 - val_loss: 1.0629
# Epoch 3/20
# 352/352 - 5s - 15ms/step - accuracy: 0.6658 - loss: 0.9479 - val_accuracy: 0.6470 - val_loss: 1.0213
# Epoch 4/20
# 352/352 - 6s - 16ms/step - accuracy: 0.6912 - loss: 0.8798 - val_accuracy: 0.6524 - val_loss: 1.0110
# Epoch 5/20
# 352/352 - 5s - 15ms/step - accuracy: 0.7114 - loss: 0.8258 - val_accuracy: 0.6436 - val_loss: 1.0290
# Epoch 6/20
# 352/352 - 6s - 16ms/step - accuracy: 0.7298 - loss: 0.7714 - val_accuracy: 0.6538 - val_loss: 1.0235
# Epoch 7/20
# 352/352 - 5s - 15ms/step - accuracy: 0.7501 - loss: 0.7161 - val_accuracy: 0.6508 - val_loss: 1.0144
# Epoch 8/20
# 352/352 - 6s - 16ms/step - accuracy: 0.7665 - loss: 0.6667 - val_accuracy: 0.6564 - val_loss: 1.0487
# Epoch 9/20
# 352/352 - 10s - 28ms/step - accuracy: 0.7844 - loss: 0.6177 - val_accuracy: 0.6426 - val_loss: 1.0646
# Epoch 10/20
# 352/352 - 6s - 16ms/step - accuracy: 0.8032 - loss: 0.5693 - val_accuracy: 0.6526 - val_loss: 1.1018
# Epoch 11/20
# 352/352 - 10s - 29ms/step - accuracy: 0.8189 - loss: 0.5262 - val_accuracy: 0.6448 - val_loss: 1.1107
# Epoch 12/20
# 352/352 - 5s - 15ms/step - accuracy: 0.8344 - loss: 0.4855 - val_accuracy: 0.6414 - val_loss: 1.1395
# Epoch 13/20
# 352/352 - 6s - 16ms/step - accuracy: 0.8486 - loss: 0.4462 - val_accuracy: 0.6404 - val_loss: 1.1849
# Epoch 14/20
# 352/352 - 5s - 15ms/step - accuracy: 0.8617 - loss: 0.4091 - val_accuracy: 0.6404 - val_loss: 1.2659
# Epoch 15/20
# 352/352 - 11s - 30ms/step - accuracy: 0.8767 - loss: 0.3743 - val_accuracy: 0.6408 - val_loss: 1.2592
# Epoch 16/20
# 352/352 - 5s - 15ms/step - accuracy: 0.8864 - loss: 0.3425 - val_accuracy: 0.6310 - val_loss: 1.3146
# Epoch 17/20
# 352/352 - 6s - 16ms/step - accuracy: 0.9001 - loss: 0.3040 - val_accuracy: 0.6354 - val_loss: 1.3669
# Epoch 18/20
# 352/352 - 10s - 30ms/step - accuracy: 0.9104 - loss: 0.2796 - val_accuracy: 0.6310 - val_loss: 1.4133
# Epoch 19/20
# 352/352 - 5s - 15ms/step - accuracy: 0.9193 - loss: 0.2530 - val_accuracy: 0.6300 - val_loss: 1.4409
# Epoch 20/20
# 352/352 - 6s - 16ms/step - accuracy: 0.9302 - loss: 0.2271 - val_accuracy: 0.6220 - val_loss: 1.5287
# Test accuracy: 0.6354

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

base_model = EfficientNetB0(include_top=False, weights='imagenet', input_shape=(32, 32, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=outputs)

# 転移学習（初期は凍結）
for layer in base_model.layers:
    layer.trainable = False

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 352/352 - 53s - 149ms/step - accuracy: 0.9300 - loss: 0.2184 - val_accuracy: 0.6252 - val_loss: 1.5584
# Epoch 2/20
# 352/352 - 9s - 25ms/step - accuracy: 0.9423 - loss: 0.1910 - val_accuracy: 0.6210 - val_loss: 1.6892
# Epoch 3/20
# 352/352 - 10s - 29ms/step - accuracy: 0.9494 - loss: 0.1708 - val_accuracy: 0.6214 - val_loss: 1.6883
# Epoch 4/20
# 352/352 - 10s - 28ms/step - accuracy: 0.9585 - loss: 0.1452 - val_accuracy: 0.6206 - val_loss: 1.7625
# Epoch 5/20
# 352/352 - 10s - 29ms/step - accuracy: 0.9636 - loss: 0.1326 - val_accuracy: 0.6168 - val_loss: 1.8658
# Epoch 6/20
# 352/352 - 6s - 17ms/step - accuracy: 0.9664 - loss: 0.1243 - val_accuracy: 0.6006 - val_loss: 2.0055
# Epoch 7/20
# 352/352 - 5s - 15ms/step - accuracy: 0.9635 - loss: 0.1241 - val_accuracy: 0.6146 - val_loss: 1.9434
# Epoch 8/20
# 352/352 - 10s - 29ms/step - accuracy: 0.9766 - loss: 0.0927 - val_accuracy: 0.6150 - val_loss: 1.9928
# Epoch 9/20
# 352/352 - 10s - 29ms/step - accuracy: 0.9798 - loss: 0.0842 - val_accuracy: 0.6126 - val_loss: 2.0572
# Epoch 10/20
# 352/352 - 6s - 16ms/step - accuracy: 0.9804 - loss: 0.0806 - val_accuracy: 0.6134 - val_loss: 2.1010
# Epoch 11/20
# 352/352 - 6s - 16ms/step - accuracy: 0.9793 - loss: 0.0796 - val_accuracy: 0.6144 - val_loss: 2.2449
# Epoch 12/20
# 352/352 - 11s - 30ms/step - accuracy: 0.9762 - loss: 0.0845 - val_accuracy: 0.6108 - val_loss: 2.2585
# Epoch 13/20
# 352/352 - 10s - 29ms/step - accuracy: 0.9828 - loss: 0.0681 - val_accuracy: 0.6110 - val_loss: 2.3580
# Epoch 14/20
# 352/352 - 5s - 16ms/step - accuracy: 0.9835 - loss: 0.0643 - val_accuracy: 0.6158 - val_loss: 2.3412
# Epoch 15/20
# 352/352 - 10s - 29ms/step - accuracy: 0.9918 - loss: 0.0437 - val_accuracy: 0.6136 - val_loss: 2.3790
# Epoch 16/20
# 352/352 - 6s - 16ms/step - accuracy: 0.9897 - loss: 0.0470 - val_accuracy: 0.6140 - val_loss: 2.4695
# Epoch 17/20
# 352/352 - 5s - 16ms/step - accuracy: 0.9734 - loss: 0.0849 - val_accuracy: 0.6068 - val_loss: 2.5264
# Epoch 18/20
# 352/352 - 6s - 17ms/step - accuracy: 0.9777 - loss: 0.0737 - val_accuracy: 0.6172 - val_loss: 2.5446
# Epoch 19/20
# 352/352 - 6s - 16ms/step - accuracy: 0.9916 - loss: 0.0400 - val_accuracy: 0.6154 - val_loss: 2.5791
# Epoch 20/20
# 352/352 - 5s - 15ms/step - accuracy: 0.9985 - loss: 0.0196 - val_accuracy: 0.6226 - val_loss: 2.5738
# Test accuracy: 0.6312

# %%
# !pip install keras-cv
# Out:
# Collecting keras-cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from keras-cv) (2024.11.6)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (from keras-cv) (4.9.9)
# Collecting keras-core (from keras-cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.11/dist-packages (from keras-cv) (0.3.12)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from kagglehub->keras-cv) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kagglehub->keras-cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kagglehub->keras-cv) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras-core->keras-cv) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras-core->keras-cv) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras-core->keras-cv) (3.14.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from keras-core->keras-cv) (0.1.9)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (0.7.2)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (5.29.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (18.1.0)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (1.17.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (3.1.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->keras-cv) (1.17.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (4.14.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (3.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub->keras-cv) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub->keras-cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub->keras-cv) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub->keras-cv) (2025.6.15)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->keras-core->keras-cv) (25.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras-core->keras-cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras-core->keras-cv) (2.19.1)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.70.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 21.6 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 54.0 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.9.0

# %%
# !pip install -U keras-cv --quiet

# %%
import keras_cv
from keras_cv.models import VisionTransformerClassifier

model = VisionTransformerClassifier.from_preset(
    "vit_b16_imagenet1k",  # 事前学習済のViT-Baseモデル
    num_classes=10,
    input_shape=(32, 32, 3)
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-48-104424820.py in <cell line: 0>()
#       1 import keras_cv
# ----> 2 from keras_cv.models import VisionTransformerClassifier
#       3
#       4 model = VisionTransformerClassifier.from_preset(
#       5     "vit_b16_imagenet1k",  # 事前学習済のViT-Baseモデル
#
# ImportError: cannot import name 'VisionTransformerClassifier' from 'keras_cv.models' (/usr/local/lib/python3.11/dist-packages/keras_cv/api/models/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.1,
    verbose=2
)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training/Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
